# %%
import json
import numpy as np
import pandas as pd
from nltk.metrics import ConfusionMatrix
from collections import *

# %%
annotes = pd.read_csv('text-difficulty-avg-annotes.csv')

# %%
session_to_difficulty = dict(zip(annotes.Session, annotes.DiffTarget))

# %%
table = pd.read_csv('table_for_prediction_updated.csv')

# %%
grade1 = table.loc[table.Grade == 'Grade1']

# %%
table = table.loc[table.Session.astype(str).isin(session_to_difficulty)]
table['DiffTarget'] = table.Session.apply(lambda s: session_to_difficulty[str(s)])

# %%
table.tail()
# Out:
#       Session          Form   Grade   WCPM    Acc  Comp  Exp  level  \
# 1210    53803  Grade4Spring  Grade4  122.0  1.000   4.4  3.7     16
# 1211    53945  Grade1Winter  Grade1   64.0  1.000   7.0  2.2      9
# 1212    54096  Grade4Winter  Grade4  124.0  0.997   5.7  3.6     17
# 1213    54166  Grade4Spring  Grade4  124.0  0.996   6.5  3.6     16
# 1214    54195    Grade4Fall  Grade4   82.0  0.695   2.0  2.3     12
#
#       WCPM_zscore  Acc_zscore  ...  gyorP  gyorQ  mlevel_numeric  \
# 1210     0.404977    0.676739  ...      3    3.0              16
# 1211     0.007175    0.877031  ...      3    3.0               9
# 1212     1.127903    0.572681  ...      3    3.0              17
# 1213     0.461105    0.624682  ...      3    3.0              16
# 1214    -0.572132   -3.891709  ...      3    3.0              12
#
#       form_numeric  mlevel_form_diff  text_is_above_level      Acc4   AvgSpan  \
# 1210            17                -1                    0  1.000000  1.000000
# 1211             6                 3                    1  1.000000  1.000000
# 1212            16                 1                    1  0.988054  1.000000
# 1213            17                -1                    0  0.984096  1.000000
# 1214            15                -3                    0  0.233313  0.970224
#
#       AccOverSpanNonSW  DiffTarget
# 1210          0.967213       Right
# 1211          0.909091       Right
# 1212          0.921875       Right
# 1213          0.950820       Right
# 1214          0.806818        Easy
#
# [5 rows x 34 columns]

# %%
diff_to_num = {
    'Right': 2,
    'Easy': 3,
    'Hard': 1
}
def get_diff_to_num(lst):
    return [diff_to_num[x] for x in lst]

# %%
def naive_prediction(category=('Form', 'Grade2Spring'), acc_thres=.95, wcpm_low_pct=25, wcpm_high_pct=75):
    table_selected = table.loc[table[category[0]] == category[1]]
    table_selected_wcpms = table_selected.WCPM
    wcpm_25th = np.percentile(table_selected_wcpms, 30)
    wcpm_75th = np.percentile(table_selected_wcpms, 75)

    prediction_column = []
    for _, row in table_selected.iterrows():
        if row['AccOverSpanNonSW'] < acc_thres:
            prediction_column.append('Hard')
        elif row['AccOverSpanNonSW'] >= acc_thres and row['WCPM'] >= wcpm_75th:
            prediction_column.append('Easy')
        else:
            prediction_column.append('Right')

    conf_mat = ConfusionMatrix(get_diff_to_num(table_selected.DiffTarget), get_diff_to_num(prediction_column))
    acc = sum(1 for x,y in zip(table_selected.DiffTarget, prediction_column) if x == y) / len(prediction_column)
    print(' = '.join(category))
    print('acc = {:.2f}%'.format(acc*100))
    print(conf_mat)

    return acc

# %%
accs = []
for g in ('1','2','3','4'):
    for t in ('Fall', 'Winter', 'Spring'):
        acc = naive_prediction(('Form', 'Grade'+g+t), acc_thres=.75)
        accs.append(acc)
print('median accuracy:', np.median(accs))
# Out:
# Form = Grade1Fall
# acc = 76.70%
#   |  1  2  3 |
# --+----------+
# 1 |<13>12  . |
# 2 |  1<40> . |
# 3 |  . 11<26>|
# --+----------+
# (row = reference; col = test)
#
# Form = Grade1Winter
# acc = 68.09%
#   |  1  2  3 |
# --+----------+
# 1 | <6>15  1 |
# 2 |  4<39> 4 |
# 3 |  .  6<19>|
# --+----------+
# (row = reference; col = test)
#
# Form = Grade1Spring
# acc = 67.00%
#   |  1  2  3 |
# --+----------+
# 1 |<10>19  . |
# 2 |  2<36> 4 |
# 3 |  .  8<21>|
# --+----------+
# (row = reference; col = test)
#
# Form = Grade2Fall
# acc = 73.79%
#   |  1  2  3 |
# --+----------+
# 1 | <8>11  . |
# 2 |  2<47> 4 |
# 3 |  1  9<21>|
# --+----------+
# (row = reference; col = test)
#
# Form = Grade2Winter
# acc = 77.67%
#   |  1  2  3 |
# --+----------+
# 1 |<17> 6  . |
# 2 |  .<44> 7 |
# 3 |  . 10<19>|
# --+----------+
# (row = reference; col = test)
#
# Form = Grade2Spring
# acc = 80.41%
#   |  1  2  3 |
# --+----------+
# 1 | <6> 6  . |
# 2 |  1<47> . |
# 3 |  . 12<25>|
# --+----------+
# (row = reference; col = test)
#
# Form = Grade3Fall
# acc = 80.39%
#   |  1  2  3 |
# --+----------+
# 1 |<12> 4  1 |
# 2 |  1<53> 8 |
# 3 |  .  6<17>|
# --+----------+
# (row = reference; col = test)
#
# Form = Grade3Winter
# acc = 66.00%
#   |  1  2  3 |
# --+----------+
# 1 | <4> 1  . |
# 2 |  3<41> 4 |
# 3 |  . 26<21>|
# --+----------+
# (row = reference; col = test)
#
# Form = Grade3Spring
# acc = 77.00%
#   |  1  2  3 |
# --+----------+
# 1 | <1> 2  . |
# 2 |  1<54> 3 |
# 3 |  . 17<22>|
# --+----------+
# (row = reference; col = test)
#
# Form = Grade4Fall
# acc = 74.00%
#   |  1  2  3 |
# --+----------+
# 1 | <5> 1  . |
# 2 |  5<52> 8 |
# 3 |  . 12<17>|
# --+----------+
# (row = reference; col = test)
#
# Form = Grade4Winter
# acc = 73.74%
#   |  1  2  3 |
# --+----------+
# 1 |<11> 3  . |
# 2 |  5<50>16 |
# 3 |  .  2<12>|
# --+----------+
# (row = reference; col = test)
#
# Form = Grade4Spring
# acc = 76.47%
#   |  1  2  3 |
# --+----------+
# 1 | <7> 8  . |
# 2 |  .<49> 5 |
# 3 |  . 11<22>|
# --+----------+
# (row = reference; col = test)
#
# median accuracy: 0.7523529411764706
