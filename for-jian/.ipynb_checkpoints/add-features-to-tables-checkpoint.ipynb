# %% [markdown]
# # Add machine-generated features (duration/f0 similarity) to tables

# %%
import json
import pandas as pd

# %%
PATH_330 = '../output/performance-scores/330_20200907.json'
PATH_2201 = '../output/performance-scores/2201_20200907.json'
PATH_2202 = '../output/performance-scores/2202_20200907.json'

# %%
df = pd.read_csv('../predicting-annotation-fields/annotations-complete.tsv', sep='\t', skiprows=4)
df = df.loc[df.Form == 'Grade2Spring'].drop_duplicates()

# %%
response_to_item = {}
response_to_session = {}
for session, item, response in zip(df.Session, df.Item, df.Response):
    response_to_item[str(int(response))] = str(int(item))
    response_to_session[str(int(response))] = str(int(session))

# %%
with open(PATH_330) as f:
    perf_scores_330 = json.load(f)
with open(PATH_2201) as f:
    perf_scores_2201 = json.load(f)
with open(PATH_2202) as f:
    perf_scores_2202 = json.load(f)

scores_to_add = {
    '330': perf_scores_330,
    '2201': perf_scores_2201,
    '2202': perf_scores_2202
}

# %%
new_feature_names = list(list(perf_scores_330.values())[0].keys())

# %%
for i in range(1, 21):
    CSV = '../predicting-annotation-fields/{}_table.csv'.format(i)
    df = pd.read_csv(CSV)
    
    for feature in new_feature_names:
        
        new_column = []
        
        for response in df.Response:
            item = response_to_item[str(int(response))]
            session = response_to_session[str(int(response))]
            
            value = scores_to_add[item][session][feature]
            new_column.append(value)
        
        df[feature] = new_column
#     df.to_csv('tables/{}_table.csv'.format(i), index=False)

# %%
score_names = [
    'best_pitch_slope_score_lower_constituents_with_pauses',
    'best_pitch_slope_score_lower_constituents_no_pauses',
    'best_pitch_slope_score_middle_constituents_with_pauses',
    'best_pitch_slope_score_middle_constituents_no_pauses',
    'best_pitch_slope_score_higher_constituents_with_pauses',
    'best_pitch_slope_score_higher_constituents_no_pauses',
    'best_duration_score_lower_constituents_with_pauses',
    'best_duration_score_lower_constituents_no_pauses',
    'best_duration_score_middle_constituents_with_pauses',
    'best_duration_score_middle_constituents_no_pauses',
    'best_duration_score_higher_constituents_with_pauses',
    'best_duration_score_higher_constituents_no_pauses'
]

# %%
session_to_scores = {}

for idx, row in df.iterrows():
    response = str(int(row.Response))
    session = response_to_session[response]
    
    scores = {
        score: row[score]
        for score in score_names
    }

    session_to_scores[session] = scores

# %%
df
# Out:
#       Response   WCPM    Acc  Comp  Exp  level  WCPM_response  Comp_response  \
# 0       544687   99.0  0.989   6.5  2.8     12           77.8            7.5
# 1       544687   99.0  0.989   6.5  2.8     12           77.8            7.5
# 2       544687   99.0  0.989   6.5  2.8     12           77.8            7.5
# 3       544687   99.0  0.989   6.5  2.8     12           77.8            7.5
# 4       544687   99.0  0.989   6.5  2.8     12           77.8            7.5
# ...        ...    ...    ...   ...  ...    ...            ...            ...
# 1088    811927  109.0  0.991   6.7  2.8     13           81.8            6.0
# 1089    811927  109.0  0.991   6.7  2.8     13           81.8            6.0
# 1090    811931  109.0  0.991   6.7  2.8     13          111.5            6.0
# 1091    811931  109.0  0.991   6.7  2.8     13          111.5            6.0
# 1092    811931  109.0  0.991   6.7  2.8     13          111.5            6.0
#
#       Exp_response  undetermined  ...  \
# 0              2.9             0  ...
# 1              2.9             0  ...
# 2              2.9             0  ...
# 3              2.9             0  ...
# 4              2.9             0  ...
# ...            ...           ...  ...
# 1088           2.6             0  ...
# 1089           2.6             0  ...
# 1090           2.3             0  ...
# 1091           2.3             0  ...
# 1092           2.3             0  ...
#
#       best_pitch_slope_score_middle_constituents_with_pauses  \
# 0                                              0.631845
# 1                                              0.631845
# 2                                              0.631845
# 3                                              0.631845
# 4                                              0.631845
# ...                                                 ...
# 1088                                           0.469381
# 1089                                           0.469381
# 1090                                           0.576632
# 1091                                           0.576632
# 1092                                           0.576632
#
#       best_pitch_slope_score_middle_constituents_no_pauses  \
# 0                                              0.591063
# 1                                              0.591063
# 2                                              0.591063
# 3                                              0.591063
# 4                                              0.591063
# ...                                                 ...
# 1088                                           0.539237
# 1089                                           0.539237
# 1090                                           0.628546
# 1091                                           0.628546
# 1092                                           0.628546
#
#       best_pitch_slope_score_higher_constituents_with_pauses  \
# 0                                              0.630761
# 1                                              0.630761
# 2                                              0.630761
# 3                                              0.630761
# 4                                              0.630761
# ...                                                 ...
# 1088                                           0.401062
# 1089                                           0.401062
# 1090                                           0.505592
# 1091                                           0.505592
# 1092                                           0.505592
#
#       best_pitch_slope_score_higher_constituents_no_pauses  \
# 0                                              0.462380
# 1                                              0.462380
# 2                                              0.462380
# 3                                              0.462380
# 4                                              0.462380
# ...                                                 ...
# 1088                                           0.553092
# 1089                                           0.553092
# 1090                                           0.511005
# 1091                                           0.511005
# 1092                                           0.511005
#
#       best_duration_score_lower_constituents_with_pauses  \
# 0                                              0.195612
# 1                                              0.195612
# 2                                              0.195612
# 3                                              0.195612
# 4                                              0.195612
# ...                                                 ...
# 1088                                           0.621405
# 1089                                           0.621405
# 1090                                           0.609700
# 1091                                           0.609700
# 1092                                           0.609700
#
#       best_duration_score_lower_constituents_no_pauses  \
# 0                                             0.395064
# 1                                             0.395064
# 2                                             0.395064
# 3                                             0.395064
# 4                                             0.395064
# ...                                                ...
# 1088                                          0.490466
# 1089                                          0.490466
# 1090                                          0.401065
# 1091                                          0.401065
# 1092                                          0.401065
#
#       best_duration_score_middle_constituents_with_pauses  \
# 0                                              0.170819
# 1                                              0.170819
# 2                                              0.170819
# 3                                              0.170819
# 4                                              0.170819
# ...                                                 ...
# 1088                                           0.644842
# 1089                                           0.644842
# 1090                                           0.611330
# 1091                                           0.611330
# 1092                                           0.611330
#
#       best_duration_score_middle_constituents_no_pauses  \
# 0                                              0.344509
# 1                                              0.344509
# 2                                              0.344509
# 3                                              0.344509
# 4                                              0.344509
# ...                                                 ...
# 1088                                           0.488442
# 1089                                           0.488442
# 1090                                           0.871387
# 1091                                           0.871387
# 1092                                           0.871387
#
#       best_duration_score_higher_constituents_with_pauses  \
# 0                                              0.166188
# 1                                              0.166188
# 2                                              0.166188
# 3                                              0.166188
# 4                                              0.166188
# ...                                                 ...
# 1088                                           0.576519
# 1089                                           0.576519
# 1090                                           0.593295
# 1091                                           0.593295
# 1092                                           0.593295
#
#       best_duration_score_higher_constituents_no_pauses
# 0                                              0.359795
# 1                                              0.359795
# 2                                              0.359795
# 3                                              0.359795
# 4                                              0.359795
# ...                                                 ...
# 1088                                           0.627925
# 1089                                           0.627925
# 1090                                           0.649937
# 1091                                           0.649937
# 1092                                           0.649937
#
# [1093 rows x 27 columns]
